# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# Step 2: Load the dataset
df = pd.read_csv(r'C:\Users\DELL\Downloads\bank\bank-full.csv', sep=';')
# Step 3: Preprocess Target and Categorical Features
df['target'] = df['y'].apply(lambda x: 1 if x == 'yes' else 0)
X = df.drop(columns=['y', 'target'])
y = df['target']

# Convert categorical features into dummy/indicator variables
X_encoded = pd.get_dummies(X, drop_first=True)

# Step 4: Split into Training and Testing Sets
X_train, X_test, y_train, y_test = train_test_split(
    X_encoded, y, test_size=0.2, random_state=42, stratify=y
)

# Step 5: Initialize and Train the Decision Tree Classifier
dt_classifier = DecisionTreeClassifier(max_depth=5, random_state=42, class_weight='balanced')
dt_classifier.fit(X_train, y_train)

# Step 6: Predictions & Evaluation
y_pred = dt_classifier.predict(X_test)

print(f"Overall Accuracy: {accuracy_score(y_test, y_pred):.4f}")
print("\nConfusion Matrix:")
print(confusion_matrix(y_test, y_pred))
print("\nClassification Report:")
print(classification_report(y_test, y_pred))

# Step 7: Save Feature Importance Plot
importances = dt_classifier.feature_importances_
indices = np.argsort(importances)[::-1]
top_k = 10
top_indices = indices[:top_k]

plt.barh(range(top_k), importances[top_indices][::-1], align='center')
plt.yticks(range(top_k), [X_encoded.columns[i] for i in top_indices][::-1])
plt.xlabel('Relative Importance')
plt.title('Top 10 Feature Importances')
plt.savefig('feature_importance.png', bbox_inches='tight')
plt.close()

# Step 8: Save Decision Tree Structure Plot
plot_tree(dt_classifier, max_depth=3, feature_names=X_encoded.columns, class_names=['No', 'Yes'], filled=True, fontsize=6)
plt.savefig('decision_tree.png', bbox_inches='tight')
plt.close()
# Out:
# Overall Accuracy: 0.7556
#
# Confusion Matrix:
# [[5919 2066]
#  [ 144  914]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.98      0.74      0.84      7985
#            1       0.31      0.86      0.45      1058
#
#     accuracy                           0.76      9043
#    macro avg       0.64      0.80      0.65      9043
# weighted avg       0.90      0.76      0.80      9043

# %% [markdown]
# # Assistant
# This error occurs because the code is trying to read a CSV file named 'bank+marketing.csv' that doesn't exist in the current working directory. The file either hasn't been downloaded, is in a different location, or has a different name.
#
# **Possible solutions:**
# 1. **File doesn't exist**: You need to download the dataset first
# 2. **Wrong file path**: The file might be in a different folder
# 3. **Different filename**: The actual file might have a slightly different name
# 4. **Wrong separator**: The file might use a different delimiter
#
# Would you like me to provide the corrected code that includes error handling and alternative approaches to load the dataset?

# %% [markdown]
# # Assistant
# This error occurs because the code is trying to read a CSV file named 'bank+marketing.csv' that doesn't exist in the current working directory. The file either hasn't been downloaded, is in a different location, or has a different name.
#
# **Possible solutions:**
# 1. **File doesn't exist**: You need to download the dataset first
# 2. **Wrong file path**: The file might be in a different folder
# 3. **Different filename**: The actual file might have a slightly different name
# 4. **Wrong separator**: The file might use a different delimiter
#
# Would you like me to provide the corrected code that includes error handling and alternative approaches to load the dataset?
